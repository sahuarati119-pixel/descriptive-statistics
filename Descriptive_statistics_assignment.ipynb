# %% [markdown]
# # Descriptive statistics Assignment

# %% [markdown]
# Easy Level

# %% [markdown]
# 1.Q1: Understanding Central Tendency (Easy)
#
# A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].What is the most representative value of their weekly sales, and why?
#
# -Mean = (10+12+11+15+14+13+12)/7=87/7=12.43
# Median = 12 → Sorted:
# Mode = 12 → Occurs twice
#
# Most representative value: 12 dozens
# Why: Mean ≈ Median ≈ Mode, so data is fairly symmetric with no outliers. The median/mode of 12 shows the typical daily sales. 12 dozens is the most frequent and middle value.

# %% [markdown]
# 2.Q2: Mean in Real Life (Easy)
#
# A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].What is the mean score, and what does it tell us about the class’s performance?
#
# -Mean = (12+15+14+16+18+20+19)/7=114/7=16.29 marks
#
#  What it tells us: The class average is 16.29 out of 20. This shows the class performed well overall, with most students scoring above 15.

# %% [markdown]
# 3.Q3: Mode in Real Life (Easy)
#
# A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is this information useful for the store manager?
#
# -Mode = 8 → Size 8 sold 3 times, more than any other size.
#
#  Why useful for store manager: The mode shows the most popular shoe size. The manager should stock more of size 8 to meet demand and avoid lost sales.

# %% [markdown]
# Medium Level
#
# 4.Q4: Median in Real Life (Medium)
#
# A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].Why is the median a better measure than the mean in this case? Calculate the median.
#
# Mean = $(8000+9500+10200+11000+50000)/5 = 88700/5 = 17,740
# Median = $10,200 → Middle value of sorted data
#
# Why median is better: The $50,000 car is an outlier. It pulls the mean up to $17,740, which is higher than 4 out of 5 cars. The median $10,200 better represents the typical used car price because it’s not affected by extreme values.

# %% [markdown]
# 5.Q5: Dispersion Introduction (Medium)
#
# A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].What does the range tell us about the variation in the student’s puzzle-solving time?
#
# -Range = Max - Min = 40 - 25 = 15 minutes
#
# What it tells us: The student’s puzzle-solving time varies by 15 minutes. Times range from 25 to 40 minutes, showing moderate inconsistency. Some days are much faster than others.

# %% [markdown]
# Q6: Range in Action (Medium)
#
# A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].Find the range. How can this help the farmer in planning his packaging?
#
# -Range = 120 - 98 = 22 kg
#
# How it helps the farmer: The 22 kg range shows harvest varies week to week. The farmer should plan packaging for at least 120 kg weeks to avoid shortages, but also know some weeks will be as low as 98 kg. Helps in inventory and logistics planning.

# %% [markdown]
# 7.Q7: Variance for Decision-Making (Medium)
#
# Two delivery companies track delivery delays (in minutes).
# Company A: variance = 6
# Company B: variance = 15
# Which company is more consistent, and why?
#
# Company A is more consistent because it has lower variance.
#
# Why: Variance measures spread of data from the mean. Lower variance means delivery delays are closer to the average and more predictable. Company B’s delays vary more, so it’s less reliable.

# %% [markdown]
# 8. Standard Deviation in Context (Hard)
#
# A finance student compares the daily price fluctuations of two cryptocurrencies.
# Coin A: standard deviation = $30Coin B: standard deviation = $120Which coin is riskier to invest in, and why?
#
# Coin B is riskier to invest in.
#
# Why: Standard deviation measures volatility. Higher SD means price fluctuates more from the average. Coin B’s price swings $120 on average vs $30 for Coin A, so losses or gains are much larger. Risk-averse investors prefer lower SD.

# %% [markdown]
# 9.Combining Measures (Hard)
#
# A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410].Find the mean and standard deviation. What do these values together tell you about the family's energy use pattern ?
#
# -Mean = (400+420+390+450+410)/5=2070/5=414 kWh
# SD = [(400−414)2+(420−414)2+(390−414)2+(450−414)2+(410−414)2]/4​
# = [196+36+576+1296+16]/4​=2120/4​=530​=23.02 kWh
#
# What these tell us: The family uses 414 kWh on average per month. The SD of 23.02 kWh is small relative to the mean, meaning usage is fairly consistent. Only one month was much higher at 450 kWh. Overall, their energy use pattern is stable.

# %% [markdown]
# 10.Q10: Practical Application (Hard)
#
# A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].Find the mean, median, mode, range, and standard deviation. What insights can these measures provideabout the player’s scoring performance?
#
# -Mean = (15+18+20+22+25+17+19+21)/8=157/8=19.625 points
# Median = (19+20)/2=19.5 → Sorted:
# Mode = No mode → All values occur once
# Range = 25 - 15 = 10 points
# SD = Σ(x−19.625)2/7​=69.875/7​=9.98​=3.16 points
#
# Insights:
#
# 1.   Performance level: Mean ≈ Median ≈ 19.5-19.6 points shows the player scores around 20 points per game consistently.
# 2.   Consistency: Low SD of 3.16 means scores don’t vary much. The player is reliable, scoring between ∼16-23 most games.
# 3.   Range: 10-point range from 15 to 25 shows the player’s best and worst games aren’t extreme.
# 4.   No mode: No single score dominates, indicating balanced performance without scoring droughts or outbursts.
# [10][12][11][15][14][13][16][18][20][19][7][8][9][25][30][27][35][40][100][105][98][110][120][400][420][390][450][410][22][17][21]
